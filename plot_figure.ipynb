# %%
ori_best = [0.202, 	0.210, 	0.220 ]
ori_wrost = [0.199, 	0.206, 	0.219  ]
ext_best=  [0.204, 	0.210 ,	0.221 ]
ext_worst = [0.200, 	0.207, 	0.217  ]
dataset =["4k","7k","24k"]

# %%
import matplotlib.pyplot as plt
# Plotting
plt.plot(dataset, ori_best, marker='o', label='Original Best', markerfacecolor='none',markeredgecolor='blue',color = "blue",linewidth=0.5)
plt.plot(dataset, ori_wrost, marker='o', label='Original Worst', markerfacecolor='blue',markeredgecolor='blue',color = "blue",linewidth=0.5)
plt.plot(dataset, ext_best, marker='s', label='Extracted Best', markerfacecolor='none',markeredgecolor='red',color = "red",linewidth=0.5)
plt.plot(dataset, ext_worst, marker='s', label='Extracted Worst', markerfacecolor='red',markeredgecolor='red',color = "red",linewidth=0.5)

# Adding labels and title
plt.xlabel('Dataset Size')
plt.ylabel('Scores')
plt.title('Comparison of Scores')
plt.legend()

# Show plot
plt.grid(True)
plt.show()
